# %% [markdown]
# Explore places to visit near Empire State Building and nearby pizza destination NY, USA

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'ZA3VOIJF0TYZRN1E24GH0TAYABWOA2TMJD0X2SONNOIUTZCN' # your Foursquare ID
CLIENT_SECRET = 'RPWJFC000NCL4ANSWHZWV3WCI3GFCX1HCQ5KAB2LFSXQSOG2' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZA3VOIJF0TYZRN1E24GH0TAYABWOA2TMJD0X2SONNOIUTZCN
# CLIENT_SECRET:RPWJFC000NCL4ANSWHZWV3WCI3GFCX1HCQ5KAB2LFSXQSOG2

# %%
#address = '102 North End Ave, New York, NY'
address = '20 W 34th St, New York, NY 10001'
#20 W 34th St, New York, NY 10001

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7486538125 -73.9853043125

# %%
search_query = 'Empire stae Building'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Empire stae Building .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5da56b75b9961d002be97696'},
#  'response': {'venues': [{'id': '43695300f964a5208c291fe3',
#     'name': 'Empire State Building',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'btwn 33rd & 34th St',
#      'lat': 40.7485995507123,
#      'lng': -73.98580648682452,
#      'distance': 42,
#      'postalCode': '10118',
#      'cc': 'US',
#      'neighborhood': 'Midtown Manhattan, New York, NY',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (btwn 33rd & 34th St)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '64514349'},
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4bcca12bb6c49c7422169491',
#     'name': '86th Floor Observation Deck',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'btwn 33rd & 34th Sts',
#      'lat': 40.74844544481811,
#      'lng': -73.98568124187432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74844544481811,
#        'lng': -73.98568124187432}],
#      'distance': 39,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (btwn 33rd & 34th Sts)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d165941735',
#       'name': 'Scenic Lookout',
#       'pluralName': 'Scenic Lookouts',
#       'shortName': 'Scenic Lookout',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '64514350'},
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '542b1d09498e5766b0b855cc',
#     'name': 'Empire State Building Gym',
#     'location': {'address': '350 Fifth Avenue Concourse Level',
#      'crossStreet': '34th & 5th St',
#      'lat': 40.74844365858246,
#      'lng': -73.9854097366333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74844365858246,
#        'lng': -73.9854097366333}],
#      'distance': 25,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 Fifth Avenue Concourse Level (34th & 5th St)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '51f91f997dd2d11b70784540',
#     'name': 'Skyline Bus Tour - Empire State Building',
#     'location': {'crossStreet': '5th Ave & W 31st St',
#      'lat': 40.74665548,
#      'lng': -73.98598909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74665548,
#        'lng': -73.98598909}],
#      'distance': 229,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['5th Ave & W 31st St',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4a9c85e9f964a520763720e3',
#     'name': 'Bank of America',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'at 34th St',
#      'lat': 40.74869263344692,
#      'lng': -73.9855054184676,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74869263344692,
#        'lng': -73.9855054184676}],
#      'distance': 17,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (at 34th St)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '5911d6b51acf113e0da70cd2',
#     'name': 'Moments - Empire State Building',
#     'location': {'address': '350 5th Ave',
#      'lat': 40.748463,
#      'lng': -73.98572,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748463,
#        'lng': -73.98572}],
#      'distance': 40,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '50228bc790e710bdfa349691',
#     'name': 'Virgo Business Centers at The Empire State Building',
#     'location': {'address': '350 5th Ave',
#      'lat': 40.74826484276548,
#      'lng': -73.98543119430542,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74826484276548,
#        'lng': -73.98543119430542}],
#      'distance': 44,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '50b6ed46e4b0a40f1ec2ab32',
#     'name': '102nd Floor Observatory',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'btwn 33rd & 34th Sts',
#      'lat': 40.748464523271515,
#      'lng': -73.98565349535549,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748464523271515,
#        'lng': -73.98565349535549}],
#      'distance': 36,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (btwn 33rd & 34th Sts)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d165941735',
#       'name': 'Scenic Lookout',
#       'pluralName': 'Scenic Lookouts',
#       'shortName': 'Scenic Lookout',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '64458943'},
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '50c36eb8e4b0309a642c1ffd',
#     'name': 'ZAGG Empire State Building',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': '34th street',
#      'lat': 40.74822265493004,
#      'lng': -73.984957103743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74822265493004,
#        'lng': -73.984957103743}],
#      'distance': 56,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (34th street)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '46864895'},
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '54e40039498e4adcc53d5bf6',
#     'name': 'empire state building grill',
#     'location': {'lat': 40.750064,
#      'lng': -73.983827,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750064,
#        'lng': -73.983827}],
#      'distance': 200,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '52a0a34b498ee648116ba4a8',
#     'name': 'Shutterstock',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': '33rd Street',
#      'lat': 40.74839196047307,
#      'lng': -73.98577779151145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74839196047307,
#        'lng': -73.98577779151145}],
#      'distance': 49,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (33rd Street)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '5a31d5aedd8442139c9d9a73',
#     'name': 'Tacombi',
#     'location': {'address': '23 W 33rd St',
#      'lat': 40.748443080374166,
#      'lng': -73.9862565226273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748443080374166,
#        'lng': -73.9862565226273}],
#      'distance': 83,
#      'postalCode': '10018',
#      'cc': 'US',
#      'neighborhood': 'Koreatown',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['23 W 33rd St',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d151941735',
#       'name': 'Taco Place',
#       'pluralName': 'Taco Places',
#       'shortName': 'Tacos',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '775870',
#      'url': 'https://www.seamless.com/menu/tacombi-empire-state-23-w-33rd-st-new-york/775870?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=775870',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4c11973dd917c928a115b662',
#     'name': 'Imperial Jets',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'Empire State Building',
#      'lat': 40.748362378725254,
#      'lng': -73.98549556732178,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748362378725254,
#        'lng': -73.98549556732178}],
#      'distance': 36,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (Empire State Building)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '52def30d498ebfafa1aee8e0',
#     'name': '1800Accountant Headquarters at The Empire State Building',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': '60th Floor',
#      'lat': 40.74803725830298,
#      'lng': -73.98489475250244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74803725830298,
#        'lng': -73.98489475250244}],
#      'distance': 76,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (60th Floor)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '5ae215f212c8f0002c5037da',
#     'name': 'Juice Press',
#     'location': {'address': '350 5th Ave, Ste 131',
#      'crossStreet': 'at 33rd St',
#      'lat': 40.74795832536063,
#      'lng': -73.98525379689323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74795832536063,
#        'lng': -73.98525379689323}],
#      'distance': 77,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave, Ste 131 (at 33rd St)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d112941735',
#       'name': 'Juice Bar',
#       'pluralName': 'Juice Bars',
#       'shortName': 'Juice Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4d9a1bdd97d06ea8c13a590b',
#     'name': 'AA Realty at Empire State Building',
#     'location': {'address': '350 5th Ave',
#      'lat': 40.747695,
#      'lng': -73.984862,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747695,
#        'lng': -73.984862}],
#      'distance': 113,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4aa44e08f964a5204f4620e3',
#     'name': 'Chipotle Mexican Grill',
#     'location': {'address': '350 5th Ave Lbby 6',
#      'crossStreet': '34th St. between Fifth & Sixth Aves.',
#      'lat': 40.748524,
#      'lng': -73.9866615,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748524,
#        'lng': -73.9866615}],
#      'distance': 115,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave Lbby 6 (34th St. between Fifth & Sixth Aves.)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4d8cc7ed12d52c0f985c5434',
#     'name': 'Kaplan International English',
#     'location': {'address': '350 5th Ave Ste 6308',
#      'lat': 40.74830875964988,
#      'lng': -73.98582262081166,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74830875964988,
#        'lng': -73.98582262081166}],
#      'distance': 58,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave Ste 6308',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4aa053a1f964a520223f20e3',
#     'name': 'Hampton Inn Manhattan-35th St/Empire State Bldg',
#     'location': {'address': '59 W 35th St',
#      'lat': 40.75029681237195,
#      'lng': -73.98643434047705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75029681237195,
#        'lng': -73.98643434047705}],
#      'distance': 206,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59 W 35th St',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '512cc07ce4b01b48c725150d',
#     'name': 'Asa Institute Empire Building',
#     'location': {'lat': 40.74812997319169,
#      'lng': -73.98885964362958,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74812997319169,
#        'lng': -73.98885964362958}],
#      'distance': 305,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10001', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1a8941735',
#       'name': 'General College & University',
#       'pluralName': 'General Colleges & Universities',
#       'shortName': 'Education',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/other_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '5091517de4b0dec0bbf35645',
#     'name': 'Jimlar',
#     'location': {'lat': 40.74809653255642,
#      'lng': -73.9853581544568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74809653255642,
#        'lng': -73.9853581544568}],
#      'distance': 62,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10118', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4da33067b521224bffc818ee',
#     'name': 'Au Bon Pain',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'at E 33rd St',
#      'lat': 40.748155323744754,
#      'lng': -73.98543247936152,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748155323744754,
#        'lng': -73.98543247936152}],
#      'distance': 56,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (at E 33rd St)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False},
#    {'id': '4bec7a04976ac9286c11610b',
#     'name': 'LR Corporate',
#     'location': {'address': '350 5th Ave',
#      'crossStreet': 'Empire State Building',
#      'lat': 40.74801,
#      'lng': -73.98685,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74801,
#        'lng': -73.98685}],
#      'distance': 148,
#      'postalCode': '10118',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['350 5th Ave (Empire State Building)',
#       'New York, NY 10118',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571122038',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...         NaN
# 1  [{'id': '4bf58dd8d48988d165941735', 'name': 'S...         NaN
# 2  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...         NaN
# 3  [{'id': '4bf58dd8d48988d12b951735', 'name': 'B...         NaN
# 4  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# 1                          NaN                    NaN          NaN    False
# 2                          NaN                    NaN          NaN    False
# 3                          NaN                    NaN          NaN    False
# 4                          NaN                    NaN          NaN    False
#
#                          id                  location.address  ...  \
# 0  43695300f964a5208c291fe3                       350 5th Ave  ...
# 1  4bcca12bb6c49c7422169491                       350 5th Ave  ...
# 2  542b1d09498e5766b0b855cc  350 Fifth Avenue Concourse Level  ...
# 3  51f91f997dd2d11b70784540                               NaN  ...
# 4  4a9c85e9f964a520763720e3                       350 5th Ave  ...
#
#                            location.formattedAddress  \
# 0  [350 5th Ave (btwn 33rd & 34th St), New York, ...
# 1  [350 5th Ave (btwn 33rd & 34th Sts), New York,...
# 2  [350 Fifth Avenue Concourse Level (34th & 5th ...
# 3  [5th Ave & W 31st St, New York, NY, United Sta...
# 4  [350 5th Ave (at 34th St), New York, NY 10118,...
#
#                              location.labeledLatLngs location.lat  \
# 0                                                NaN    40.748600
# 1  [{'label': 'display', 'lat': 40.74844544481811...    40.748445
# 2  [{'label': 'display', 'lat': 40.74844365858246...    40.748444
# 3  [{'label': 'display', 'lat': 40.74665548, 'lng...    40.746655
# 4  [{'label': 'display', 'lat': 40.74869263344692...    40.748693
#
#   location.lng            location.neighborhood location.postalCode  \
# 0   -73.985806  Midtown Manhattan, New York, NY               10118
# 1   -73.985681                              NaN               10118
# 2   -73.985410                              NaN               10118
# 3   -73.985989                              NaN                 NaN
# 4   -73.985505                              NaN               10118
#
#   location.state                                      name    referralId  \
# 0             NY                     Empire State Building  v-1571122038
# 1             NY               86th Floor Observation Deck  v-1571122038
# 2             NY                 Empire State Building Gym  v-1571122038
# 3             NY  Skyline Bus Tour - Empire State Building  v-1571122038
# 4             NY                           Bank of America  v-1571122038
#
#   venuePage.id
# 0     64514349
# 1     64514350
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0                               Empire State Building
# 1                         86th Floor Observation Deck
# 2                           Empire State Building Gym
# 3            Skyline Bus Tour - Empire State Building
# 4                                     Bank of America
# 5                     Moments - Empire State Building
# 6   Virgo Business Centers at The Empire State Bui...
# 7                             102nd Floor Observatory
# 8                          ZAGG Empire State Building
# 9                         empire state building grill
# 10                                       Shutterstock
# 11                                            Tacombi
# 12                                      Imperial Jets
# 13  1800Accountant Headquarters at The Empire Stat...
# 14                                        Juice Press
# 15                 AA Realty at Empire State Building
# 16                             Chipotle Mexican Grill
# 17                       Kaplan International English
# 18    Hampton Inn Manhattan-35th St/Empire State Bldg
# 19                      Asa Institute Empire Building
# 20                                             Jimlar
# 21                                        Au Bon Pain
# 22                                       LR Corporate
#
#                       categories                           address  cc  \
# 0                       Building                       350 5th Ave  US
# 1                 Scenic Lookout                       350 5th Ave  US
# 2           Gym / Fitness Center  350 Fifth Avenue Concourse Level  US
# 3                       Bus Line                               NaN  US
# 4                           Bank                       350 5th Ave  US
# 5                           None                       350 5th Ave  US
# 6                         Office                       350 5th Ave  US
# 7                 Scenic Lookout                       350 5th Ave  US
# 8              Electronics Store                       350 5th Ave  US
# 9            American Restaurant                               NaN  US
# 10                  Tech Startup                       350 5th Ave  US
# 11                    Taco Place                      23 W 33rd St  US
# 12                        Office                       350 5th Ave  US
# 13                        Office                       350 5th Ave  US
# 14                     Juice Bar              350 5th Ave, Ste 131  US
# 15                      Building                       350 5th Ave  US
# 16            Mexican Restaurant                350 5th Ave Lbby 6  US
# 17               Language School              350 5th Ave Ste 6308  US
# 18                         Hotel                      59 W 35th St  US
# 19  General College & University                               NaN  US
# 20                        Office                               NaN  US
# 21                        Bakery                       350 5th Ave  US
# 22                        Office                       350 5th Ave  US
#
#         city        country                           crossStreet  distance  \
# 0   New York  United States                   btwn 33rd & 34th St        42
# 1   New York  United States                  btwn 33rd & 34th Sts        39
# 2   New York  United States                         34th & 5th St        25
# 3   New York  United States                   5th Ave & W 31st St       229
# 4   New York  United States                            at 34th St        17
# 5   New York  United States                                   NaN        40
# 6   New York  United States                                   NaN        44
# 7   New York  United States                  btwn 33rd & 34th Sts        36
# 8   New York  United States                           34th street        56
# 9   New York  United States                                   NaN       200
# 10  New York  United States                           33rd Street        49
# 11  New York  United States                                   NaN        83
# 12  New York  United States                 Empire State Building        36
# 13  New York  United States                            60th Floor        76
# 14  New York  United States                            at 33rd St        77
# 15  New York  United States                                   NaN       113
# 16  New York  United States  34th St. between Fifth & Sixth Aves.       115
# 17  New York  United States                                   NaN        58
# 18  New York  United States                                   NaN       206
# 19  New York  United States                                   NaN       305
# 20  New York  United States                                   NaN        62
# 21  New York  United States                          at E 33rd St        56
# 22  New York  United States                 Empire State Building       148
#
#                                      formattedAddress  \
# 0   [350 5th Ave (btwn 33rd & 34th St), New York, ...
# 1   [350 5th Ave (btwn 33rd & 34th Sts), New York,...
# 2   [350 Fifth Avenue Concourse Level (34th & 5th ...
# 3   [5th Ave & W 31st St, New York, NY, United Sta...
# 4   [350 5th Ave (at 34th St), New York, NY 10118,...
# 5    [350 5th Ave, New York, NY 10118, United States]
# 6    [350 5th Ave, New York, NY 10118, United States]
# 7   [350 5th Ave (btwn 33rd & 34th Sts), New York,...
# 8   [350 5th Ave (34th street), New York, NY 10118...
# 9                       [New York, NY, United States]
# 10  [350 5th Ave (33rd Street), New York, NY 10118...
# 11  [23 W 33rd St, New York, NY 10018, United States]
# 12  [350 5th Ave (Empire State Building), New York...
# 13  [350 5th Ave (60th Floor), New York, NY 10118,...
# 14  [350 5th Ave, Ste 131 (at 33rd St), New York, ...
# 15   [350 5th Ave, New York, NY 10118, United States]
# 16  [350 5th Ave Lbby 6 (34th St. between Fifth & ...
# 17  [350 5th Ave Ste 6308, New York, NY 10118, Uni...
# 18  [59 W 35th St, New York, NY 10001, United States]
# 19                [New York, NY 10001, United States]
# 20                [New York, NY 10118, United States]
# 21  [350 5th Ave (at E 33rd St), New York, NY 1011...
# 22  [350 5th Ave (Empire State Building), New York...
#
#                                        labeledLatLngs        lat        lng  \
# 0                                                 NaN  40.748600 -73.985806
# 1   [{'label': 'display', 'lat': 40.74844544481811...  40.748445 -73.985681
# 2   [{'label': 'display', 'lat': 40.74844365858246...  40.748444 -73.985410
# 3   [{'label': 'display', 'lat': 40.74665548, 'lng...  40.746655 -73.985989
# 4   [{'label': 'display', 'lat': 40.74869263344692...  40.748693 -73.985505
# 5   [{'label': 'display', 'lat': 40.748463, 'lng':...  40.748463 -73.985720
# 6   [{'label': 'display', 'lat': 40.74826484276548...  40.748265 -73.985431
# 7   [{'label': 'display', 'lat': 40.74846452327151...  40.748465 -73.985653
# 8   [{'label': 'display', 'lat': 40.74822265493004...  40.748223 -73.984957
# 9   [{'label': 'display', 'lat': 40.750064, 'lng':...  40.750064 -73.983827
# 10  [{'label': 'display', 'lat': 40.74839196047307...  40.748392 -73.985778
# 11  [{'label': 'display', 'lat': 40.74844308037416...  40.748443 -73.986257
# 12  [{'label': 'display', 'lat': 40.74836237872525...  40.748362 -73.985496
# 13  [{'label': 'display', 'lat': 40.74803725830298...  40.748037 -73.984895
# 14  [{'label': 'display', 'lat': 40.74795832536063...  40.747958 -73.985254
# 15  [{'label': 'display', 'lat': 40.747695, 'lng':...  40.747695 -73.984862
# 16  [{'label': 'display', 'lat': 40.748524, 'lng':...  40.748524 -73.986661
# 17  [{'label': 'display', 'lat': 40.74830875964988...  40.748309 -73.985823
# 18  [{'label': 'display', 'lat': 40.75029681237195...  40.750297 -73.986434
# 19  [{'label': 'display', 'lat': 40.74812997319169...  40.748130 -73.988860
# 20  [{'label': 'display', 'lat': 40.74809653255642...  40.748097 -73.985358
# 21  [{'label': 'display', 'lat': 40.74815532374475...  40.748155 -73.985432
# 22  [{'label': 'display', 'lat': 40.74801, 'lng': ...  40.748010 -73.986850
#
#                        neighborhood postalCode state                        id
# 0   Midtown Manhattan, New York, NY      10118    NY  43695300f964a5208c291fe3
# 1                               NaN      10118    NY  4bcca12bb6c49c7422169491
# 2                               NaN      10118    NY  542b1d09498e5766b0b855cc
# 3                               NaN        NaN    NY  51f91f997dd2d11b70784540
# 4                               NaN      10118    NY  4a9c85e9f964a520763720e3
# 5                               NaN      10118    NY  5911d6b51acf113e0da70cd2
# 6                               NaN      10118    NY  50228bc790e710bdfa349691
# 7                               NaN      10118    NY  50b6ed46e4b0a40f1ec2ab32
# 8                               NaN      10118    NY  50c36eb8e4b0309a642c1ffd
# 9                               NaN        NaN    NY  54e40039498e4adcc53d5bf6
# 10                              NaN      10118    NY  52a0a34b498ee648116ba4a8
# 11                        Koreatown      10018    NY  5a31d5aedd8442139c9d9a73
# 12                              NaN      10118    NY  4c11973dd917c928a115b662
# 13                              NaN      10118    NY  52def30d498ebfafa1aee8e0
# 14                              NaN      10118    NY  5ae215f212c8f0002c5037da
# 15                              NaN      10118    NY  4d9a1bdd97d06ea8c13a590b
# 16                              NaN      10118    NY  4aa44e08f964a5204f4620e3
# 17                              NaN      10118    NY  4d8cc7ed12d52c0f985c5434
# 18                              NaN      10001    NY  4aa053a1f964a520223f20e3
# 19                              NaN      10001    NY  512cc07ce4b01b48c725150d
# 20                              NaN      10118    NY  5091517de4b0dec0bbf35645
# 21                              NaN      10118    NY  4da33067b521224bffc818ee
# 22                              NaN      10118    NY  4bec7a04976ac9286c11610b

# %% [markdown]
# Let's visualize the pizza destinations that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                                 Empire State Building
# 1                           86th Floor Observation Deck
# 2                             Empire State Building Gym
# 3              Skyline Bus Tour - Empire State Building
# 4                                       Bank of America
# 5                       Moments - Empire State Building
# 6     Virgo Business Centers at The Empire State Bui...
# 7                               102nd Floor Observatory
# 8                            ZAGG Empire State Building
# 9                           empire state building grill
# 10                                         Shutterstock
# 11                                              Tacombi
# 12                                        Imperial Jets
# 13    1800Accountant Headquarters at The Empire Stat...
# 14                                          Juice Press
# 15                   AA Realty at Empire State Building
# 16                               Chipotle Mexican Grill
# 17                         Kaplan International English
# 18      Hampton Inn Manhattan-35th St/Empire State Bldg
# 19                        Asa Institute Empire Building
# 20                                               Jimlar
# 21                                          Au Bon Pain
# 22                                         LR Corporate
# Name: name, dtype: object

# %% [markdown]
# Ratings for Places to visit nearby Empire State Building

# %%
#86th Floor Observation Deck
venue_id = '4bcca12bb6c49c7422169491'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.0

# %%
#Bryant Park
venue_id = '3fd66200f964a520d7f11ee3'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.6

# %%
#Museum of Modern Art (MoMA)
venue_id = '4af5a46af964a520b5fa21e3'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.3

# %%
#Intrepid Sea, Air & Space Museum
venue_id = '49f5135cf964a5208e6b1fe3'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.1

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Empire stae Building

# add a red circle marker to represent Empire stae Building
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Empire stae Building',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Places to visit as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's explore Pizza destination--near Empire State Building

# %%
search_query1 = 'PIZZA'
radius = 500
print(search_query1 + ' .... OK!')
# Out:
# PIZZA .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=ZA3VOIJF0TYZRN1E24GH0TAYABWOA2TMJD0X2SONNOIUTZCN&client_secret=RPWJFC000NCL4ANSWHZWV3WCI3GFCX1HCQ5KAB2LFSXQSOG2&ll=40.7486538125,-73.9853043125&v=20180604&query=PIZZA&radius=500&limit=50'

# %%
results1 = requests.get(url).json()
results1
# Out:
# {'meta': {'code': 200, 'requestId': '5da56f67724750002c5a85f2'},
#  'response': {'venues': [{'id': '49dceb2ff964a520be5f1fe3',
#     'name': 'Little Italy Pizza',
#     'location': {'address': '2 E 33rd St',
#      'crossStreet': 'at 5th Ave',
#      'lat': 40.747688976569115,
#      'lng': -73.98488286795896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747688976569115,
#        'lng': -73.98488286795896}],
#      'distance': 113,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2 E 33rd St (at 5th Ave)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '65092',
#      'url': 'https://www.seamless.com/menu/little-italy-pizza-2-e-33rd-st-new-york/65092?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=65092',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5851a76b0393cc0b7003d204',
#     'name': 'Fresh Pizza 99 Cents',
#     'location': {'address': '1032 Avenue of the Americas',
#      'lat': 40.752858573980326,
#      'lng': -73.98563395601224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752858573980326,
#        'lng': -73.98563395601224}],
#      'distance': 468,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1032 Avenue of the Americas',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4a6a002ef964a52058cc1fe3',
#     'name': 'Bravo Pizza',
#     'location': {'address': '107 W 37th St',
#      'crossStreet': 'at Broadway',
#      'lat': 40.752163,
#      'lng': -73.987817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752163,
#        'lng': -73.987817}],
#      'distance': 444,
#      'postalCode': '10018',
#      'cc': 'US',
#      'neighborhood': 'Garment District',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['107 W 37th St (at Broadway)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '497289',
#      'url': 'https://www.seamless.com/menu/bravo-kosher-pizza-107-w-37th-st-new-york/497289?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=497289',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'venuePage': {'id': '93085999'},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4c163ecaa9c220a1f34a5a9d',
#     'name': 'Café Bonjour Deli & Pizza',
#     'location': {'address': '18 W 38th St',
#      'crossStreet': '5th Avenue',
#      'lat': 40.75134984419345,
#      'lng': -73.98376227889581,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75134984419345,
#        'lng': -73.98376227889581}],
#      'distance': 327,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 W 38th St (5th Avenue)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '117444846'},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4b05e0a8f964a520ffe422e3',
#     'name': 'Penn Pizza',
#     'location': {'address': '33rd St Penn Station',
#      'crossStreet': 'Between 7th & 8th',
#      'lat': 40.748429943251026,
#      'lng': -73.98891703333011,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.748429943251026,
#        'lng': -73.98891703333011}],
#      'distance': 305,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['33rd St Penn Station (Between 7th & 8th)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4b16b831f964a52080bc23e3',
#     'name': 'Sabinas Pizza',
#     'location': {'address': '150 W 36th St',
#      'crossStreet': 'btw Broadway & 7th Ave.',
#      'lat': 40.75136978768057,
#      'lng': -73.9887161693032,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75136978768057,
#        'lng': -73.9887161693032}],
#      'distance': 417,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['150 W 36th St (btw Broadway & 7th Ave.)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '534440c5498ee031ceec8d89',
#     'name': "Jimmy's New York Style Pizza Store in Macy's",
#     'location': {'address': "Macy's 34th St",
#      'lat': 40.75196507279782,
#      'lng': -73.98634021886579,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75196507279782,
#        'lng': -73.98634021886579}],
#      'distance': 378,
#      'cc': 'US',
#      'city': 'Manhattan',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ["Macy's 34th St", 'Manhattan, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4ce4134377ef224b869a467b',
#     'name': "Jimmy's Pizza",
#     'location': {'address': '151 W 34th St',
#      'crossStreet': 'btwn 7th Ave & Broadway',
#      'lat': 40.75085656582931,
#      'lng': -73.98906624647115,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75085656582931,
#        'lng': -73.98906624647115}],
#      'distance': 400,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['151 W 34th St (btwn 7th Ave & Broadway)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4bb534dbf562ef3bc8ab2e97',
#     'name': "Caruso's Pizza",
#     'location': {'address': 'Penn Station',
#      'lat': 40.750420147454754,
#      'lng': -73.99141700030881,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750420147454754,
#        'lng': -73.99141700030881}],
#      'distance': 551,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Penn Station', 'New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '594076b2840fc235e72564c2',
#     'name': '&pizza',
#     'location': {'address': '15 W 28th St',
#      'crossStreet': 'Broadway',
#      'lat': 40.74520457937066,
#      'lng': -73.98823142051697,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74520457937066,
#        'lng': -73.98823142051697}],
#      'distance': 456,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['15 W 28th St (Broadway)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '778349',
#      'url': 'https://www.seamless.com/menu/pizza-15-w-28th-st-new-york/778349?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=778349',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5a32dc066a59502016afedbb',
#     'name': 'Pizza Market',
#     'location': {'crossStreet': '29th Street',
#      'lat': 40.746467,
#      'lng': -73.990096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.746467,
#        'lng': -73.990096}],
#      'distance': 471,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['29th Street',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '596e509fda5ede571682a7ae',
#     'name': "Frankie Boy's Pizza",
#     'location': {'address': '1387 Broadway',
#      'crossStreet': '37th St',
#      'lat': 40.752058533089986,
#      'lng': -73.98759536950614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752058533089986,
#        'lng': -73.98759536950614}],
#      'distance': 425,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1387 Broadway (37th St)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '411906',
#      'url': 'https://www.seamless.com/menu/frankie-boys-pizza-1367-broadway-new-york/411906?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=411906',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4b7dc8d0f964a52070d42fe3',
#     'name': "Gyro II & Spinellli's Pizza",
#     'location': {'address': 'Penn Station',
#      'lat': 40.750591477209824,
#      'lng': -73.99111994703438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750591477209824,
#        'lng': -73.99111994703438}],
#      'distance': 535,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Penn Station',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4bdeff34e75c0f47f58ac903',
#     'name': 'Little Italy Pizza',
#     'location': {'address': '401 7th Ave',
#      'crossStreet': 'at W 33rd St',
#      'lat': 40.75028536023766,
#      'lng': -73.99108712692482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75028536023766,
#        'lng': -73.99108712692482}],
#      'distance': 520,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['401 7th Ave (at W 33rd St)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '101340',
#      'url': 'https://www.seamless.com/menu/little-italy-pizza-401-7th-ave-new-york/101340?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=101340',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4e4c4433bd413c4cc6681600',
#     'name': "Tony's Pizza & Restaurant",
#     'location': {'address': '58 W 31st St',
#      'lat': 40.74841545734378,
#      'lng': -73.98573761806597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74841545734378,
#        'lng': -73.98573761806597}],
#      'distance': 45,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['58 W 31st St',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5c28745fa6031c002c9c3343',
#     'name': '99 Cent Pizza',
#     'location': {'lat': 40.747924,
#      'lng': -73.988946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747924,
#        'lng': -73.988946}],
#      'distance': 317,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10001', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4ee0e96f9a52e7f5b945d51b',
#     'name': 'Pizza And Deli',
#     'location': {'address': '18 E 33rd St',
#      'crossStreet': '5th Avenue',
#      'lat': 40.747715736796074,
#      'lng': -73.98478493103883,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747715736796074,
#        'lng': -73.98478493103883}],
#      'distance': 113,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 E 33rd St (5th Avenue)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4c4c6ad09c8d2d7f3f3c656c',
#     'name': "Pizza Pete's",
#     'location': {'lat': 40.747316833333336,
#      'lng': -73.98538455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747316833333336,
#        'lng': -73.98538455}],
#      'distance': 148,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10001', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5787b226498e4a619c8b1dfd',
#     'name': 'DJ Pizza',
#     'location': {'address': '120 E 34th St',
#      'crossStreet': 'Lexington Ave',
#      'lat': 40.746377,
#      'lng': -73.979977,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.746377,
#        'lng': -73.979977}],
#      'distance': 515,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 E 34th St (Lexington Ave)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '59f0c2f3a30619599ab17a77',
#     'name': '99 Cent Famous Pizza',
#     'location': {'lat': 40.744522,
#      'lng': -73.98667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744522,
#        'lng': -73.98667}],
#      'distance': 474,
#      'postalCode': '10016',
#      'cc': 'US',
#      'neighborhood': 'NoMad',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10016', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '591962',
#      'url': 'https://www.seamless.com/menu/99-cents-famous-pizza-1-e-28-st-new-york/591962?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=591962',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '570bdac9498efb0ebb5e011a',
#     'name': 'pizza bar NYC',
#     'location': {'address': '151 W 34th St',
#      'crossStreet': '7th Ave',
#      'lat': 40.75126581611452,
#      'lng': -73.98932433572696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75126581611452,
#        'lng': -73.98932433572696}],
#      'distance': 446,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['151 W 34th St (7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4f325a1619836c91c7cf474d',
#     'name': 'Big Georges Pizza',
#     'location': {'address': '333 5th Ave',
#      'lat': 40.747773,
#      'lng': -73.985046,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747773,
#        'lng': -73.985046}],
#      'distance': 100,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['333 5th Ave',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5301bcf0498e5531e169aae7',
#     'name': 'Dollar Pizza',
#     'location': {'lat': 40.747491,
#      'lng': -73.985338,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747491,
#        'lng': -73.985338}],
#      'distance': 129,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10001', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5c105a14916bc1002cf9976e',
#     'name': 'Famous Pizza',
#     'location': {'address': '1 E 28th St',
#      'crossStreet': '5th Ave',
#      'lat': 40.744576,
#      'lng': -73.9868,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.744576,
#        'lng': -73.9868}],
#      'distance': 471,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 E 28th St (5th Ave)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4c913af451d9b1f794c37e46',
#     'name': 'New York Style Pizza',
#     'location': {'lat': 40.747333,
#      'lng': -73.985039,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747333,
#        'lng': -73.985039}],
#      'distance': 148,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10016', 'United States']},
#     'categories': [],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4e31ab97483b1bbfc5b04d38',
#     'name': 'Pizza Shop',
#     'location': {'address': '151 W 34th St',
#      'crossStreet': 'btwn 7th Ave & Broadway',
#      'lat': 40.75109495964447,
#      'lng': -73.98717811778722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75109495964447,
#        'lng': -73.98717811778722}],
#      'distance': 314,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['151 W 34th St (btwn 7th Ave & Broadway)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4fb286b9e4b0a8c8112a6cae',
#     'name': 'Little Italy Pizza',
#     'location': {'address': '185 West 32nd St',
#      'crossStreet': '7th Ave',
#      'lat': 40.74953607151918,
#      'lng': -73.99109935054356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74953607151918,
#        'lng': -73.99109935054356}],
#      'distance': 498,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['185 West 32nd St (7th Ave)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '268135',
#      'url': 'https://www.seamless.com/menu/little-italy-pizza-185-w-32nd-st-new-york/268135?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=268135',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4c3c8482933b0f470a24e421',
#     'name': 'Pizza Truck',
#     'location': {'address': 'Broadway & 30th st',
#      'lat': 40.746547602610086,
#      'lng': -73.98870469135245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.746547602610086,
#        'lng': -73.98870469135245}],
#      'distance': 370,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Broadway & 30th st',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4c069b8a8b4520a1dfa98597',
#     'name': 'K Food Pizza',
#     'location': {'address': '18 E 33rd St',
#      'crossStreet': 'btw Madison & 5th Ave',
#      'lat': 40.747438,
#      'lng': -73.98423492908478,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747438,
#        'lng': -73.98423492908478}],
#      'distance': 162,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['18 E 33rd St (btw Madison & 5th Ave)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4a5e8adbf964a520bebe1fe3',
#     'name': 'Pizza Mercato',
#     'location': {'address': '120 E 34th St',
#      'crossStreet': 'at Lexington',
#      'lat': 40.74633939186087,
#      'lng': -73.98017064508767,
#      'distance': 503,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 E 34th St (at Lexington)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4b5c856df964a520243429e3',
#     'name': 'Aroma Pizza',
#     'location': {'address': '35 W 36th St',
#      'crossStreet': 'Btw 6th and 5th Ave',
#      'lat': 40.750783,
#      'lng': -73.985548,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750783,
#        'lng': -73.985548}],
#      'distance': 237,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['35 W 36th St (Btw 6th and 5th Ave)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5da110df2c1e910008c61f82',
#     'name': 'New Balance Pizza Co',
#     'location': {'address': '47 E 34th St',
#      'lat': 40.747642,
#      'lng': -73.982298,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747642,
#        'lng': -73.982298}],
#      'distance': 277,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['47 E 34th St',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5d9e6b959766eb00080ed268',
#     'name': 'NB Pizza',
#     'location': {'address': '47 East 47th Street',
#      'lat': 40.747378,
#      'lng': -73.982372,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747378,
#        'lng': -73.982372}],
#      'distance': 285,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['47 East 47th Street',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4fbbc277e4b0efa7dacfaaee',
#     'name': 'Pizza king',
#     'location': {'address': '1011 Avenue of the Americas',
#      'crossStreet': 'W 38th Street',
#      'lat': 40.75213066517214,
#      'lng': -73.98606847937803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75213066517214,
#        'lng': -73.98606847937803}],
#      'distance': 392,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1011 Avenue of the Americas (W 38th Street)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4f3211e619833175d60d85bf',
#     'name': 'Best Ray Pizza',
#     'location': {'address': '58 W 31st St',
#      'lat': 40.747607,
#      'lng': -73.988435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.747607,
#        'lng': -73.988435}],
#      'distance': 288,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['58 W 31st St',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4b9c1baef964a520e14a36e3',
#     'name': '6th Avenue Coffee & Pizza Shop',
#     'location': {'address': '1013 Avenue of the Americas',
#      'crossStreet': '38th Street',
#      'lat': 40.7521314,
#      'lng': -73.98592807,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7521314,
#        'lng': -73.98592807}],
#      'distance': 390,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1013 Avenue of the Americas (38th Street)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4db19ab97abaff58538d458f',
#     'name': "Papa John's Pizza",
#     'location': {'address': '12 E 37th St',
#      'crossStreet': 'btwn Madison & 5th Ave.',
#      'lat': 40.749899158425436,
#      'lng': -73.98219863248106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.749899158425436,
#        'lng': -73.98219863248106}],
#      'distance': 296,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['12 E 37th St (btwn Madison & 5th Ave.)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4b53397df964a520fe9227e3',
#     'name': 'Enrico Caruso Pizza',
#     'location': {'address': 'Penn Station - LIRR',
#      'crossStreet': '7th Ave @ 32nd St',
#      'lat': 40.750415,
#      'lng': -73.991502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750415,
#        'lng': -73.991502}],
#      'distance': 558,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Penn Station - LIRR (7th Ave @ 32nd St)',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4cc5e55d3ed5199c9b6a4b1e',
#     'name': "Frank's Pizza",
#     'location': {'address': '333 7th Ave',
#      'crossStreet': '29th Street',
#      'lat': 40.74715832807931,
#      'lng': -73.98975492100332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74715832807931,
#        'lng': -73.98975492100332}],
#      'distance': 410,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['333 7th Ave (29th Street)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5cdee4ab04d1ae002cea203a',
#     'name': 'Pn Woodfired Pizza',
#     'location': {'address': '246 5th Ave',
#      'lat': 40.74488,
#      'lng': -73.987847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74488,
#        'lng': -73.987847}],
#      'distance': 471,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['246 5th Ave',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '5cf7c99e588e36002c327ae2',
#     'name': 'Spin City Records & Pizza',
#     'location': {'address': '460 Park Ave S',
#      'lat': 40.7450919,
#      'lng': -73.98312949999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7450919,
#        'lng': -73.98312949999999}],
#      'distance': 436,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['460 Park Ave S',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '545592a2498e5c511030e53b',
#     'name': 'Bravo Kosher Pizza',
#     'location': {'address': '1367 Broadway',
#      'lat': 40.751733237722114,
#      'lng': -73.98748228566909,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.751733237722114,
#        'lng': -73.98748228566909}],
#      'distance': 388,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1367 Broadway',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '52cb01f011d234eecfed6007',
#     'name': 'Star Gourmet Deli & Pizza',
#     'location': {'address': '797 Avenue of the Americas',
#      'crossStreet': 'W 27th St',
#      'lat': 40.746574533214684,
#      'lng': -73.99010499627633,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.746574533214684,
#        'lng': -73.99010499627633}],
#      'distance': 466,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['797 Avenue of the Americas (W 27th St)',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4e860e67f790d3f8d90b96cd',
#     'name': '32nd Street Pizza',
#     'location': {'address': '32nd off 7th',
#      'lat': 40.74961903992198,
#      'lng': -73.99120728684836,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74961903992198,
#        'lng': -73.99120728684836}],
#      'distance': 509,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['32nd off 7th', 'New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123047',
#     'hasPerk': False},
#    {'id': '4f3322fae4b0a676eba7b4e6',
#     'name': 'Pizza King',
#     'location': {'address': '120 E 34th St',
#      'crossStreet': 'at Lexington Ave.',
#      'lat': 40.746504839312884,
#      'lng': -73.97992251598323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.746504839312884,
#        'lng': -73.97992251598323}],
#      'distance': 513,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['120 E 34th St (at Lexington Ave.)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123048',
#     'hasPerk': False},
#    {'id': '4a708910f964a520b8d71fe3',
#     'name': 'Zimari Pizza',
#     'location': {'address': '113 E 31st St',
#      'crossStreet': 'Park',
#      'lat': 40.745058568697154,
#      'lng': -73.98189240653575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.745058568697154,
#        'lng': -73.98189240653575}],
#      'distance': 492,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['113 E 31st St (Park)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123048',
#     'hasPerk': False},
#    {'id': '4c5c4659d25320a1dfb5c27a',
#     'name': "Original Ray's Pizza",
#     'location': {'address': '341 Lexington Ave',
#      'crossStreet': '39th',
#      'lat': 40.74939151028625,
#      'lng': -73.97870713573151,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74939151028625,
#        'lng': -73.97870713573151}],
#      'distance': 562,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['341 Lexington Ave (39th)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123048',
#     'hasPerk': False},
#    {'id': '50004f6ee4b04dd3f9d1ab32',
#     'name': 'Breakfast Lunch Pizza',
#     'location': {'lat': 40.74479,
#      'lng': -73.988743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74479,
#        'lng': -73.988743}],
#      'distance': 518,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10001', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123048',
#     'hasPerk': False},
#    {'id': '4db853e843a1a75c1f70b89d',
#     'name': 'In-N-Out Pizza',
#     'location': {'address': '6Ave',
#      'lat': 40.752869,
#      'lng': -73.985897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752869,
#        'lng': -73.985897}],
#      'distance': 471,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['6Ave', 'New York, NY 10018', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123048',
#     'hasPerk': False},
#    {'id': '4e0cd1a3483b3608f10c6333',
#     'name': '$1.00 In- N- Out Pizza',
#     'location': {'crossStreet': '6th avenue and 39th street',
#      'lat': 40.752901,
#      'lng': -73.9851104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752901,
#        'lng': -73.9851104}],
#      'distance': 473,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['6th avenue and 39th street',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571123048',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results1['response']['venues']

# tranform venues into a dataframe
dataframe1 = json_normalize(venues)
dataframe1.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...       65092
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...      497289
# 3  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...         NaN
# 4  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...         NaN
#
#                 delivery.provider.icon.name  \
# 0  /delivery_provider_seamless_20180129.png
# 1                                       NaN
# 2  /delivery_provider_seamless_20180129.png
# 3                                       NaN
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0               seamless  https://www.seamless.com/menu/little-italy-piz...
# 1                    NaN                                                NaN
# 2               seamless  https://www.seamless.com/menu/bravo-kosher-piz...
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
#
#    hasPerk                        id             location.address  ...  \
# 0    False  49dceb2ff964a520be5f1fe3                  2 E 33rd St  ...
# 1    False  5851a76b0393cc0b7003d204  1032 Avenue of the Americas  ...
# 2    False  4a6a002ef964a52058cc1fe3                107 W 37th St  ...
# 3    False  4c163ecaa9c220a1f34a5a9d                 18 W 38th St  ...
# 4    False  4b05e0a8f964a520ffe422e3         33rd St Penn Station  ...
#
#                            location.formattedAddress  \
# 0  [2 E 33rd St (at 5th Ave), New York, NY 10016,...
# 1  [1032 Avenue of the Americas, New York, NY 100...
# 2  [107 W 37th St (at Broadway), New York, NY 100...
# 3  [18 W 38th St (5th Avenue), New York, NY 10018...
# 4  [33rd St Penn Station (Between 7th & 8th), New...
#
#                              location.labeledLatLngs location.lat  \
# 0  [{'label': 'display', 'lat': 40.74768897656911...    40.747689
# 1  [{'label': 'display', 'lat': 40.75285857398032...    40.752859
# 2  [{'label': 'display', 'lat': 40.752163, 'lng':...    40.752163
# 3  [{'label': 'display', 'lat': 40.75134984419345...    40.751350
# 4  [{'label': 'display', 'lat': 40.74842994325102...    40.748430
#
#   location.lng  location.neighborhood location.postalCode location.state  \
# 0   -73.984883                    NaN               10016             NY
# 1   -73.985634                    NaN               10018             NY
# 2   -73.987817       Garment District               10018             NY
# 3   -73.983762                    NaN               10018             NY
# 4   -73.988917                    NaN               10001             NY
#
#                         name    referralId venuePage.id
# 0         Little Italy Pizza  v-1571123047          NaN
# 1       Fresh Pizza 99 Cents  v-1571123047          NaN
# 2                Bravo Pizza  v-1571123047     93085999
# 3  Café Bonjour Deli & Pizza  v-1571123047    117444846
# 4                 Penn Pizza  v-1571123047          NaN
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe1.columns if col.startswith('location.')] + ['id']
dataframe1_filtered = dataframe1.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category1_type(row):
    try:
        categories1_list = row['categories']
    except:
        categories1_list = row['venue.categories']
        
    if len(categories1_list) == 0:
        return None
    else:
        return categories1_list[0]['name']

# filter the category for each row
dataframe1_filtered['categories'] = dataframe1_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe1_filtered.columns = [column.split('.')[-1] for column in dataframe1_filtered.columns]

dataframe1_filtered
# Out:
#                                             name           categories  \
# 0                             Little Italy Pizza          Pizza Place
# 1                           Fresh Pizza 99 Cents          Pizza Place
# 2                                    Bravo Pizza          Pizza Place
# 3                      Café Bonjour Deli & Pizza        Deli / Bodega
# 4                                     Penn Pizza          Pizza Place
# 5                                  Sabinas Pizza          Pizza Place
# 6   Jimmy's New York Style Pizza Store in Macy's          Pizza Place
# 7                                  Jimmy's Pizza          Pizza Place
# 8                                 Caruso's Pizza          Pizza Place
# 9                                         &pizza          Pizza Place
# 10                                  Pizza Market          Pizza Place
# 11                           Frankie Boy's Pizza          Pizza Place
# 12                   Gyro II & Spinellli's Pizza     Greek Restaurant
# 13                            Little Italy Pizza          Pizza Place
# 14                     Tony's Pizza & Restaurant          Pizza Place
# 15                                 99 Cent Pizza          Pizza Place
# 16                                Pizza And Deli          Pizza Place
# 17                                  Pizza Pete's          Pizza Place
# 18                                      DJ Pizza          Pizza Place
# 19                          99 Cent Famous Pizza          Pizza Place
# 20                                 pizza bar NYC  American Restaurant
# 21                             Big Georges Pizza          Pizza Place
# 22                                  Dollar Pizza          Pizza Place
# 23                                  Famous Pizza          Pizza Place
# 24                          New York Style Pizza                 None
# 25                                    Pizza Shop          Pizza Place
# 26                            Little Italy Pizza          Pizza Place
# 27                                   Pizza Truck          Pizza Place
# 28                                  K Food Pizza          Pizza Place
# 29                                 Pizza Mercato          Pizza Place
# 30                                   Aroma Pizza          Pizza Place
# 31                          New Balance Pizza Co          Pizza Place
# 32                                      NB Pizza          Pizza Place
# 33                                    Pizza king          Pizza Place
# 34                                Best Ray Pizza          Pizza Place
# 35                6th Avenue Coffee & Pizza Shop          Pizza Place
# 36                             Papa John's Pizza          Pizza Place
# 37                           Enrico Caruso Pizza          Pizza Place
# 38                                 Frank's Pizza          Pizza Place
# 39                            Pn Woodfired Pizza          Pizza Place
# 40                     Spin City Records & Pizza          Pizza Place
# 41                            Bravo Kosher Pizza          Pizza Place
# 42                     Star Gourmet Deli & Pizza        Deli / Bodega
# 43                             32nd Street Pizza          Pizza Place
# 44                                    Pizza King          Pizza Place
# 45                                  Zimari Pizza          Pizza Place
# 46                          Original Ray's Pizza          Pizza Place
# 47                         Breakfast Lunch Pizza          Pizza Place
# 48                                In-N-Out Pizza          Pizza Place
# 49                        $1.00 In- N- Out Pizza          Pizza Place
#
#                         address  cc       city        country  \
# 0                   2 E 33rd St  US   New York  United States
# 1   1032 Avenue of the Americas  US   New York  United States
# 2                 107 W 37th St  US   New York  United States
# 3                  18 W 38th St  US   New York  United States
# 4          33rd St Penn Station  US   New York  United States
# 5                 150 W 36th St  US   New York  United States
# 6                Macy's 34th St  US  Manhattan  United States
# 7                 151 W 34th St  US   New York  United States
# 8                  Penn Station  US   New York  United States
# 9                  15 W 28th St  US   New York  United States
# 10                          NaN  US   New York  United States
# 11                1387 Broadway  US   New York  United States
# 12                 Penn Station  US   New York  United States
# 13                  401 7th Ave  US   New York  United States
# 14                 58 W 31st St  US   New York  United States
# 15                          NaN  US   New York  United States
# 16                 18 E 33rd St  US   New York  United States
# 17                          NaN  US   New York  United States
# 18                120 E 34th St  US   New York  United States
# 19                          NaN  US   New York  United States
# 20                151 W 34th St  US   New York  United States
# 21                  333 5th Ave  US   New York  United States
# 22                          NaN  US   New York  United States
# 23                  1 E 28th St  US   New York  United States
# 24                          NaN  US   New York  United States
# 25                151 W 34th St  US   New York  United States
# 26             185 West 32nd St  US   New York  United States
# 27           Broadway & 30th st  US   New York  United States
# 28                 18 E 33rd St  US   New York  United States
# 29                120 E 34th St  US   New York  United States
# 30                 35 W 36th St  US   New York  United States
# 31                 47 E 34th St  US   New York  United States
# 32          47 East 47th Street  US   New York  United States
# 33  1011 Avenue of the Americas  US   New York  United States
# 34                 58 W 31st St  US   New York  United States
# 35  1013 Avenue of the Americas  US   New York  United States
# 36                 12 E 37th St  US   New York  United States
# 37          Penn Station - LIRR  US   New York  United States
# 38                  333 7th Ave  US   New York  United States
# 39                  246 5th Ave  US   New York  United States
# 40               460 Park Ave S  US   New York  United States
# 41                1367 Broadway  US   New York  United States
# 42   797 Avenue of the Americas  US   New York  United States
# 43                 32nd off 7th  US        NaN  United States
# 44                120 E 34th St  US   New York  United States
# 45                113 E 31st St  US   New York  United States
# 46            341 Lexington Ave  US   New York  United States
# 47                          NaN  US   New York  United States
# 48                         6Ave  US   New York  United States
# 49                          NaN  US   New York  United States
#
#                    crossStreet  distance  \
# 0                   at 5th Ave       113
# 1                          NaN       468
# 2                  at Broadway       444
# 3                   5th Avenue       327
# 4            Between 7th & 8th       305
# 5      btw Broadway & 7th Ave.       417
# 6                          NaN       378
# 7      btwn 7th Ave & Broadway       400
# 8                          NaN       551
# 9                     Broadway       456
# 10                 29th Street       471
# 11                     37th St       425
# 12                         NaN       535
# 13                at W 33rd St       520
# 14                         NaN        45
# 15                         NaN       317
# 16                  5th Avenue       113
# 17                         NaN       148
# 18               Lexington Ave       515
# 19                         NaN       474
# 20                     7th Ave       446
# 21                         NaN       100
# 22                         NaN       129
# 23                     5th Ave       471
# 24                         NaN       148
# 25     btwn 7th Ave & Broadway       314
# 26                     7th Ave       498
# 27                         NaN       370
# 28       btw Madison & 5th Ave       162
# 29                at Lexington       503
# 30         Btw 6th and 5th Ave       237
# 31                         NaN       277
# 32                         NaN       285
# 33               W 38th Street       392
# 34                         NaN       288
# 35                 38th Street       390
# 36     btwn Madison & 5th Ave.       296
# 37           7th Ave @ 32nd St       558
# 38                 29th Street       410
# 39                         NaN       471
# 40                         NaN       436
# 41                         NaN       388
# 42                   W 27th St       466
# 43                         NaN       509
# 44           at Lexington Ave.       513
# 45                        Park       492
# 46                        39th       562
# 47                         NaN       518
# 48                         NaN       471
# 49  6th avenue and 39th street       473
#
#                                      formattedAddress  \
# 0   [2 E 33rd St (at 5th Ave), New York, NY 10016,...
# 1   [1032 Avenue of the Americas, New York, NY 100...
# 2   [107 W 37th St (at Broadway), New York, NY 100...
# 3   [18 W 38th St (5th Avenue), New York, NY 10018...
# 4   [33rd St Penn Station (Between 7th & 8th), New...
# 5   [150 W 36th St (btw Broadway & 7th Ave.), New ...
# 6      [Macy's 34th St, Manhattan, NY, United States]
# 7   [151 W 34th St (btwn 7th Ave & Broadway), New ...
# 8         [Penn Station, New York, NY, United States]
# 9   [15 W 28th St (Broadway), New York, NY 10001, ...
# 10   [29th Street, New York, NY 10001, United States]
# 11  [1387 Broadway (37th St), New York, NY 10018, ...
# 12  [Penn Station, New York, NY 10001, United States]
# 13  [401 7th Ave (at W 33rd St), New York, NY 1000...
# 14  [58 W 31st St, New York, NY 10001, United States]
# 15                [New York, NY 10001, United States]
# 16  [18 E 33rd St (5th Avenue), New York, NY 10016...
# 17                [New York, NY 10001, United States]
# 18  [120 E 34th St (Lexington Ave), New York, NY 1...
# 19                [New York, NY 10016, United States]
# 20  [151 W 34th St (7th Ave), New York, NY 10001, ...
# 21   [333 5th Ave, New York, NY 10016, United States]
# 22                [New York, NY 10001, United States]
# 23  [1 E 28th St (5th Ave), New York, NY 10016, Un...
# 24                [New York, NY 10016, United States]
# 25  [151 W 34th St (btwn 7th Ave & Broadway), New ...
# 26  [185 West 32nd St (7th Ave), New York, NY 1000...
# 27  [Broadway & 30th st, New York, NY, United States]
# 28  [18 E 33rd St (btw Madison & 5th Ave), New Yor...
# 29  [120 E 34th St (at Lexington), New York, NY 10...
# 30  [35 W 36th St (Btw 6th and 5th Ave), New York,...
# 31  [47 E 34th St, New York, NY 10016, United States]
# 32  [47 East 47th Street, New York, NY 10016, Unit...
# 33  [1011 Avenue of the Americas (W 38th Street), ...
# 34  [58 W 31st St, New York, NY 10001, United States]
# 35  [1013 Avenue of the Americas (38th Street), Ne...
# 36  [12 E 37th St (btwn Madison & 5th Ave.), New Y...
# 37  [Penn Station - LIRR (7th Ave @ 32nd St), New ...
# 38  [333 7th Ave (29th Street), New York, NY 10001...
# 39   [246 5th Ave, New York, NY 10001, United States]
# 40  [460 Park Ave S, New York, NY 10016, United St...
# 41  [1367 Broadway, New York, NY 10018, United Sta...
# 42  [797 Avenue of the Americas (W 27th St), New Y...
# 43            [32nd off 7th, New York, United States]
# 44  [120 E 34th St (at Lexington Ave.), New York, ...
# 45  [113 E 31st St (Park), New York, NY 10016, Uni...
# 46  [341 Lexington Ave (39th), New York, NY 10016,...
# 47                [New York, NY 10001, United States]
# 48          [6Ave, New York, NY 10018, United States]
# 49  [6th avenue and 39th street, New York, NY 1001...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 40.74768897656911...  40.747689 -73.984883
# 1   [{'label': 'display', 'lat': 40.75285857398032...  40.752859 -73.985634
# 2   [{'label': 'display', 'lat': 40.752163, 'lng':...  40.752163 -73.987817
# 3   [{'label': 'display', 'lat': 40.75134984419345...  40.751350 -73.983762
# 4   [{'label': 'display', 'lat': 40.74842994325102...  40.748430 -73.988917
# 5   [{'label': 'display', 'lat': 40.75136978768057...  40.751370 -73.988716
# 6   [{'label': 'display', 'lat': 40.75196507279782...  40.751965 -73.986340
# 7   [{'label': 'display', 'lat': 40.75085656582931...  40.750857 -73.989066
# 8   [{'label': 'display', 'lat': 40.75042014745475...  40.750420 -73.991417
# 9   [{'label': 'display', 'lat': 40.74520457937066...  40.745205 -73.988231
# 10  [{'label': 'display', 'lat': 40.746467, 'lng':...  40.746467 -73.990096
# 11  [{'label': 'display', 'lat': 40.75205853308998...  40.752059 -73.987595
# 12  [{'label': 'display', 'lat': 40.75059147720982...  40.750591 -73.991120
# 13  [{'label': 'display', 'lat': 40.75028536023766...  40.750285 -73.991087
# 14  [{'label': 'display', 'lat': 40.74841545734378...  40.748415 -73.985738
# 15  [{'label': 'display', 'lat': 40.747924, 'lng':...  40.747924 -73.988946
# 16  [{'label': 'display', 'lat': 40.74771573679607...  40.747716 -73.984785
# 17  [{'label': 'display', 'lat': 40.74731683333333...  40.747317 -73.985385
# 18  [{'label': 'display', 'lat': 40.746377, 'lng':...  40.746377 -73.979977
# 19  [{'label': 'display', 'lat': 40.744522, 'lng':...  40.744522 -73.986670
# 20  [{'label': 'display', 'lat': 40.75126581611452...  40.751266 -73.989324
# 21  [{'label': 'display', 'lat': 40.747773, 'lng':...  40.747773 -73.985046
# 22  [{'label': 'display', 'lat': 40.747491, 'lng':...  40.747491 -73.985338
# 23  [{'label': 'display', 'lat': 40.744576, 'lng':...  40.744576 -73.986800
# 24  [{'label': 'display', 'lat': 40.747333, 'lng':...  40.747333 -73.985039
# 25  [{'label': 'display', 'lat': 40.75109495964447...  40.751095 -73.987178
# 26  [{'label': 'display', 'lat': 40.74953607151918...  40.749536 -73.991099
# 27  [{'label': 'display', 'lat': 40.74654760261008...  40.746548 -73.988705
# 28  [{'label': 'display', 'lat': 40.747438, 'lng':...  40.747438 -73.984235
# 29                                                NaN  40.746339 -73.980171
# 30  [{'label': 'display', 'lat': 40.750783, 'lng':...  40.750783 -73.985548
# 31  [{'label': 'display', 'lat': 40.747642, 'lng':...  40.747642 -73.982298
# 32  [{'label': 'display', 'lat': 40.747378, 'lng':...  40.747378 -73.982372
# 33  [{'label': 'display', 'lat': 40.75213066517214...  40.752131 -73.986068
# 34  [{'label': 'display', 'lat': 40.747607, 'lng':...  40.747607 -73.988435
# 35  [{'label': 'display', 'lat': 40.7521314, 'lng'...  40.752131 -73.985928
# 36  [{'label': 'display', 'lat': 40.74989915842543...  40.749899 -73.982199
# 37  [{'label': 'display', 'lat': 40.750415, 'lng':...  40.750415 -73.991502
# 38  [{'label': 'display', 'lat': 40.74715832807931...  40.747158 -73.989755
# 39  [{'label': 'display', 'lat': 40.74488, 'lng': ...  40.744880 -73.987847
# 40  [{'label': 'display', 'lat': 40.7450919, 'lng'...  40.745092 -73.983129
# 41  [{'label': 'display', 'lat': 40.75173323772211...  40.751733 -73.987482
# 42  [{'label': 'display', 'lat': 40.74657453321468...  40.746575 -73.990105
# 43  [{'label': 'display', 'lat': 40.74961903992198...  40.749619 -73.991207
# 44  [{'label': 'display', 'lat': 40.74650483931288...  40.746505 -73.979923
# 45  [{'label': 'display', 'lat': 40.74505856869715...  40.745059 -73.981892
# 46  [{'label': 'display', 'lat': 40.74939151028625...  40.749392 -73.978707
# 47  [{'label': 'display', 'lat': 40.74479, 'lng': ...  40.744790 -73.988743
# 48  [{'label': 'display', 'lat': 40.752869, 'lng':...  40.752869 -73.985897
# 49  [{'label': 'display', 'lat': 40.752901, 'lng':...  40.752901 -73.985110
#
#         neighborhood postalCode     state                        id
# 0                NaN      10016        NY  49dceb2ff964a520be5f1fe3
# 1                NaN      10018        NY  5851a76b0393cc0b7003d204
# 2   Garment District      10018        NY  4a6a002ef964a52058cc1fe3
# 3                NaN      10018        NY  4c163ecaa9c220a1f34a5a9d
# 4                NaN      10001        NY  4b05e0a8f964a520ffe422e3
# 5                NaN      10018        NY  4b16b831f964a52080bc23e3
# 6                NaN        NaN        NY  534440c5498ee031ceec8d89
# 7                NaN      10001        NY  4ce4134377ef224b869a467b
# 8                NaN        NaN        NY  4bb534dbf562ef3bc8ab2e97
# 9                NaN      10001        NY  594076b2840fc235e72564c2
# 10               NaN      10001        NY  5a32dc066a59502016afedbb
# 11               NaN      10018        NY  596e509fda5ede571682a7ae
# 12               NaN      10001        NY  4b7dc8d0f964a52070d42fe3
# 13               NaN      10001        NY  4bdeff34e75c0f47f58ac903
# 14               NaN      10001        NY  4e4c4433bd413c4cc6681600
# 15               NaN      10001        NY  5c28745fa6031c002c9c3343
# 16               NaN      10016        NY  4ee0e96f9a52e7f5b945d51b
# 17               NaN      10001        NY  4c4c6ad09c8d2d7f3f3c656c
# 18               NaN      10016        NY  5787b226498e4a619c8b1dfd
# 19             NoMad      10016        NY  59f0c2f3a30619599ab17a77
# 20               NaN      10001        NY  570bdac9498efb0ebb5e011a
# 21               NaN      10016        NY  4f325a1619836c91c7cf474d
# 22               NaN      10001        NY  5301bcf0498e5531e169aae7
# 23               NaN      10016        NY  5c105a14916bc1002cf9976e
# 24               NaN      10016        NY  4c913af451d9b1f794c37e46
# 25               NaN      10001        NY  4e31ab97483b1bbfc5b04d38
# 26               NaN      10001        NY  4fb286b9e4b0a8c8112a6cae
# 27               NaN        NaN        NY  4c3c8482933b0f470a24e421
# 28               NaN      10016        NY  4c069b8a8b4520a1dfa98597
# 29               NaN      10016        NY  4a5e8adbf964a520bebe1fe3
# 30               NaN      10018        NY  4b5c856df964a520243429e3
# 31               NaN      10016        NY  5da110df2c1e910008c61f82
# 32               NaN      10016        NY  5d9e6b959766eb00080ed268
# 33               NaN      10018        NY  4fbbc277e4b0efa7dacfaaee
# 34               NaN      10001        NY  4f3211e619833175d60d85bf
# 35               NaN      10018        NY  4b9c1baef964a520e14a36e3
# 36               NaN      10016        NY  4db19ab97abaff58538d458f
# 37               NaN      10018        NY  4b53397df964a520fe9227e3
# 38               NaN      10001        NY  4cc5e55d3ed5199c9b6a4b1e
# 39               NaN      10001        NY  5cdee4ab04d1ae002cea203a
# 40               NaN      10016        NY  5cf7c99e588e36002c327ae2
# 41               NaN      10018        NY  545592a2498e5c511030e53b
# 42               NaN      10001        NY  52cb01f011d234eecfed6007
# 43               NaN        NaN  New York  4e860e67f790d3f8d90b96cd
# 44               NaN      10016        NY  4f3322fae4b0a676eba7b4e6
# 45               NaN      10016        NY  4a708910f964a520b8d71fe3
# 46               NaN      10016        NY  4c5c4659d25320a1dfb5c27a
# 47               NaN      10001        NY  50004f6ee4b04dd3f9d1ab32
# 48               NaN      10018        NY  4db853e843a1a75c1f70b89d
# 49               NaN      10018        NY  4e0cd1a3483b3608f10c6333

# %% [markdown]
# New codes add to search pizzaa

# %% [markdown]
# Let's check the ratings of  some randamoly selected pizza destinations

# %%
#Little Italy Pizza è4bce2087b6c49c74739a9691
venue_id = '4a8c31aef964a520410d20e3'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.5

# %%
#Gyro II & Spinellli's Pizza 
venue_id = '4b7dc8d0f964a52070d42fe3'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
     
except:
    print('This venue has not been rated yet.')
# Out:
# 6.6

# %%
#Café Bonjour Deli & Pizza
venue_id = '4c163ecaa9c220a1f34a5a9d'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.9

# %%
#Franks Pizza
venue_id = '4bca37c5cc8cd13a1f42bdcf'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.7

# %%
# Bravo Pizza	
venue_id = '4bd4eeff29eb9c7497b092e1'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
result = requests.get(url).json()
#print(result['response']['venue'].keys())
result['response']['venue']
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.0

# %% [markdown]
# Explore a location

# %% [markdown]
# Popular spots around the Four Seasons Ny

# %%
#latitude = 40.7626
#longitude = -73.9712
latitude = 40.7626
longitude = -73.9712
#40.7486538125 -73.9853043125

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=ZA3VOIJF0TYZRN1E24GH0TAYABWOA2TMJD0X2SONNOIUTZCN&client_secret=RPWJFC000NCL4ANSWHZWV3WCI3GFCX1HCQ5KAB2LFSXQSOG2&ll=40.7626,-73.9712&v=20180604&radius=500&limit=50'

# %%
import requests
results = requests.get(url).json()
'There are {} around Four Seasons Ny.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 50 around Four Seasons Ny.'

# %% [markdown]
# Relevant part of JSON

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4a8eb444f964a5207e1220e3',
#   'name': 'Four Seasons Hotel',
#   'location': {'address': '57 E 57th St',
#    'crossStreet': 'btwn Madison & Park Ave',
#    'lat': 40.76194512106052,
#    'lng': -73.97174099158845,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.76194512106052,
#      'lng': -73.97174099158845}],
#    'distance': 85,
#    'postalCode': '10022',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['57 E 57th St (btwn Madison & Park Ave)',
#     'New York, NY 10022',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1fa931735',
#     'name': 'Hotel',
#     'pluralName': 'Hotels',
#     'shortName': 'Hotel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4a8eb444f964a5207e1220e3-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                   name          categories          address  cc      city  \
# 0   Four Seasons Hotel               Hotel     57 E 57th St  US  New York
# 1        Saint Laurent            Boutique      3 W 57th St  US  New York
# 2             Phillips         Art Gallery     450 Park Ave  US  New York
# 3    Jim's Shoe Repair          Shoe Store     50 E 59th St  US  New York
# 4   Apple Fifth Avenue   Electronics Store      767 5th Ave  US  New York
# 5           Mizu Salon                 Spa  505 Park Avenue  US  New York
# 6        Tiffany & Co.       Jewelry Store      727 5th Ave  US  New York
# 7  Pierre Michel Salon  Salon / Barbershop    135 E 57th St  US  New York
# 8  Mark Garrison Salon  Salon / Barbershop    108 E 60th St  US  New York
# 9            BLT Steak          Steakhouse    106 E 57th St  US  New York
#
#          country               crossStreet  distance  \
# 0  United States   btwn Madison & Park Ave        85
# 1  United States  btwn 5th Ave and 6th Ave       207
# 2  United States              at E 57th St       118
# 3  United States              Madison/Park        90
# 4  United States   btwn E 58th & E 59th St       164
# 5  United States                at 59th St       135
# 6  United States              at E 57th St       212
# 7  United States          Lexington Avenue       194
# 8  United States  Between Lexinton and Prk       202
# 9  United States               at Park Ave       149
#
#                                     formattedAddress  \
# 0  [57 E 57th St (btwn Madison & Park Ave), New Y...
# 1  [3 W 57th St (btwn 5th Ave and 6th Ave), New Y...
# 2  [450 Park Ave (at E 57th St), New York, NY 100...
# 3  [50 E 59th St (Madison/Park), New York, NY 100...
# 4  [767 5th Ave (btwn E 58th & E 59th St), New Yo...
# 5  [505 Park Avenue (at 59th St), New York, NY 10...
# 6  [727 5th Ave (at E 57th St), New York, NY 1002...
# 7  [135 E 57th St (Lexington Avenue), New York, N...
# 8  [108 E 60th St (Between Lexinton and Prk), New...
# 9  [106 E 57th St (at Park Ave), New York, NY 100...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.76194512106052...  40.761945 -73.971741
# 1  [{'label': 'display', 'lat': 40.76287247392285...  40.762872 -73.973633
# 2  [{'label': 'display', 'lat': 40.76155276452638...  40.761553 -73.970956
# 3  [{'label': 'display', 'lat': 40.7634125732713,...  40.763413 -73.971106
# 4  [{'label': 'display', 'lat': 40.76347583811899...  40.763476 -73.972778
# 5  [{'label': 'display', 'lat': 40.76306602956480...  40.763066 -73.969712
# 6  [{'label': 'display', 'lat': 40.7627046, 'lng'...  40.762705 -73.973721
# 7  [{'label': 'display', 'lat': 40.76131599263822...  40.761316 -73.969641
# 8  [{'label': 'display', 'lat': 40.7632, 'lng': -...  40.763200 -73.968930
# 9  [{'label': 'display', 'lat': 40.76149679392716...  40.761497 -73.970197
#
#   neighborhood postalCode state                        id
# 0          NaN      10022    NY  4a8eb444f964a5207e1220e3
# 1          NaN      10019    NY  4b20181bf964a5201e2d24e3
# 2          NaN      10022    NY  4cd872323ec4b1f75289be3f
# 3          NaN      10022    NY  4aae5732f964a520df6120e3
# 4          NaN      10153    NY  447bf8f1f964a520ec331fe3
# 5          NaN      10022    NY  4a9eeabff964a520c83b20e3
# 6          NaN      10022    NY  4613c5bef964a52041451fe3
# 7          NaN      10022    NY  4b48ba8ef964a520605426e3
# 8          NaN      10022    NY  4b6060cdf964a5209ee229e3
# 9          NaN      10022    NY  45814450f964a520613f1fe3
